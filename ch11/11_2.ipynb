# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# p.219~ p.228

# %%
#from datetime import datetime
import datetime as dt
day = dt.datetime(year=2021, month=7, day=4)
day
# Out:
# datetime.datetime(2021, 7, 4, 0, 0)

# %%
dt.datetime.strptime('2025-07-30', '%Y-%m-%d')
# Out:
# datetime.datetime(2025, 7, 30, 0, 0)

# %%
today = dt.datetime(2025,7,30)
today + dt.timedelta(2)
# Out:
# datetime.datetime(2025, 8, 1, 0, 0)

# %%
#Monday == 1
day.isoweekday()
# Out:
# 7

# %%
# Monday == 0
day.weekday()
# Out:
# 6

# %%
from dateutil import parser
date = parser.parse("4th of July, 2021")
date
# Out:
# datetime.datetime(2021, 7, 4, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Sunday'

# %%
date.strftime('%A'), date.strftime('%B'), date.strftime('%C'), date.strftime('%D')
# Out:
# ('Sunday', 'July', '20', '07/04/21')

# %% [markdown]
# #### Numpy에서의 날짜와 시간

# %%
import numpy as np
date = np.array('2021-07-04', dtype=np.datetime64)
date
# Out:
# array('2021-07-04', dtype='datetime64[D]')

# %%
date.size
# Out:
# 1

# %%
date + np.arange(12)
# Out:
# array(['2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07',
#        '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#        '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2021-07-04')
# Out:
# np.datetime64('2021-07-04')

# %%
np.datetime64('2021-07-04 12:00')
# Out:
# np.datetime64('2021-07-04T12:00')

# %%
np.datetime64('2021-07-04 12:59:59.50', 'ns')
# Out:
# np.datetime64('2021-07-04T12:59:59.500000000')

# %%
np.datetime64('2021-07-04') + np.arange(12)
# Out:
# array(['2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07',
#        '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#        '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#       dtype='datetime64[D]')

# %% [markdown]
# #### Pandas에서의 날짜와 시간

# %%
import pandas as pd
date = pd.to_datetime('4th of July, 2021')
date
# Out:
# Timestamp('2021-07-04 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Sunday'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07',
#                '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#                '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
# Pandas 시계열: 시간으로 인덱싱하기
index = pd.DatetimeIndex([
    '2020-07-04', '2020-08-04',
    '2021-07-04', '2021-08-04'
])

data = pd.Series([0,1,2,3], index=index)
data
# Out:
# 2020-07-04    0
# 2020-08-04    1
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %% [markdown]
# p.234

# %%
weather_url = 'https://raw.githubusercontent.com/jakevdp/bicycle-data/refs/heads/main/SeattleWeather.csv'
weather_df = pd.read_csv(weather_url)

# %%
weather_df.head()
# Out:
#        STATION                           NAME        DATE   AWND  FMTM  PGTM  \
# 0  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2012-01-01  10.51   NaN   NaN
# 1  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2012-01-02  10.07   NaN   NaN
# 2  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2012-01-03   5.14   NaN   NaN
# 3  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2012-01-04  10.51   NaN   NaN
# 4  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2012-01-05  13.65   NaN   NaN
#
#    PRCP  SNOW  SNWD  TAVG  ...  WT04  WT05  WT08  WT09  WT13  WT14  WT16  \
# 0  0.00   0.0   0.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 1  0.43   0.0   0.0   NaN  ...   NaN   NaN   NaN   NaN   1.0   NaN   1.0
# 2  0.03   0.0   0.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# 3  0.80   0.0   0.0   NaN  ...   NaN   NaN   NaN   NaN   1.0   NaN   1.0
# 4  0.05   0.0   0.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   1.0
#
#    WT17  WT18  WT22
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# ...

# %%
bicycle_url = 'https://raw.githubusercontent.com/jakevdp/bicycle-data/refs/heads/main/FremontBridge.csv'
bicycle_df = pd.read_csv(bicycle_url)

# %%
bicycle_df.head()
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0  11/01/2019 12:00:00 AM                  12.0                           7.0
# 1  11/01/2019 01:00:00 AM                   7.0                           0.0
# 2  11/01/2019 02:00:00 AM                   1.0                           0.0
# 3  11/01/2019 03:00:00 AM                   6.0                           6.0
# 4  11/01/2019 04:00:00 AM                   6.0                           5.0
#
#    Fremont Bridge West Sidewalk
# 0                           5.0
# 1                           7.0
# 2                           1.0
# 3                           0.0
# 4                           1.0

# %%
pd.to_datetime(bicycle_df['Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15516\279645206.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(bicycle_df['Date'])
# 0        2019-11-01 00:00:00
# 1        2019-11-01 01:00:00
# 2        2019-11-01 02:00:00
# 3        2019-11-01 03:00:00
# 4        2019-11-01 04:00:00
#                  ...
# 147273   2021-12-31 19:00:00
# 147274   2021-12-31 20:00:00
# 147275   2021-12-31 21:00:00
# 147276   2021-12-31 22:00:00
# 147277   2021-12-31 23:00:00
# Name: Date, Length: 147278, dtype: datetime64[ns]

# %%
bicycle_df['Date'] = pd.to_datetime(bicycle_df['Date'], format='%m/%d/%Y %H:%M:%S %p') # 포맷을 지정해주면 실행 속도가 더 빨라진다!

# %%
bicycle_df = bicycle_df.sort_values('Date')

# %%
bicycle_df = bicycle_df.set_index(['Date'])

# %%
bicycle_df.index
# Out:
# DatetimeIndex(['2012-10-03 01:00:00', '2012-10-03 01:00:00',
#                '2012-10-03 01:00:00', '2012-10-03 01:00:00',
#                '2012-10-03 02:00:00', '2012-10-03 02:00:00',
#                '2012-10-03 02:00:00', '2012-10-03 02:00:00',
#                '2012-10-03 03:00:00', '2012-10-03 03:00:00',
#                ...
#                '2021-12-31 08:00:00', '2021-12-31 08:00:00',
#                '2021-12-31 09:00:00', '2021-12-31 09:00:00',
#                '2021-12-31 10:00:00', '2021-12-31 10:00:00',
#                '2021-12-31 11:00:00', '2021-12-31 11:00:00',
#                '2021-12-31 12:00:00', '2021-12-31 12:00:00'],
#               dtype='datetime64[ns]', name='Date', length=147278, freq=None)

# %%
bicycle_df.index.is_monotonic_increasing
# Out:
# True

# %%
bicycle_df.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 01:00:00                  90.0                          42.0
# 2012-10-03 01:00:00                  90.0                          42.0
# 2012-10-03 02:00:00                 128.0                          77.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 01:00:00                          48.0
# 2012-10-03 01:00:00                          48.0
# 2012-10-03 02:00:00                          51.0

# %%
import yfinance as yf
ticker = 'TSLA'
df= yf.download(ticker, start='2020-01-01', end='2025-07-29')
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15516\3960475791.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticker, start='2020-01-01', end='2025-07-29')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df.loc[:, ('Close', 'TSLA')]
# Out:
# Date
# 2020-01-02     28.684000
# 2020-01-03     29.534000
# 2020-01-06     30.102667
# 2020-01-07     31.270666
# 2020-01-08     32.809334
#                  ...
# 2025-07-22    332.109985
# 2025-07-23    332.559998
# 2025-07-24    305.299988
# 2025-07-25    316.059998
# 2025-07-28    325.589996
# Name: (Close, TSLA), Length: 1399, dtype: float64

# %%
df.loc[:, ('Close', 'TSLA')].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# p.230

# %%
import yfinance as yf
tsla_df = yf.download('TSLA', start='2020-01-01', end='2025-07-29')
tsla_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15516\2994570407.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tsla_df = yf.download('TSLA', start='2020-01-01', end='2025-07-29')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
tsla_df.columns
# Out:
# MultiIndex([( 'Close', 'TSLA'),
#             (  'High', 'TSLA'),
#             (   'Low', 'TSLA'),
#             (  'Open', 'TSLA'),
#             ('Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
tsla_df.columns = tsla_df.columns.droplevel(1)

# %%
tsla_df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
tsla_df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
# 문제를 간단히 만들기 위해 종가만 사용
tsla_df = tsla_df['Close']

# %%
tsla_df.resample('BYE').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_df.resample('Q').mean().plot()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15516\43146002.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   tsla_df.resample('Q').mean().plot()
# <Axes: xlabel='Date'>

# %%
tsla_df.asfreq('B').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_df.asfreq('BA').plot()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15516\346366983.py:1: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   tsla_df.asfreq('BA').plot()
# <Axes: xlabel='Date'>

# %%
tsla_df
# Out:
# Date
# 2020-01-02     28.684000
# 2020-01-03     29.534000
# 2020-01-06     30.102667
# 2020-01-07     31.270666
# 2020-01-08     32.809334
#                  ...
# 2025-07-22    332.109985
# 2025-07-23    332.559998
# 2025-07-24    305.299988
# 2025-07-25    316.059998
# 2025-07-28    325.589996
# Name: Close, Length: 1399, dtype: float64

# %%
tsla_df.shift(-365)
# Out:
# Date
# 2020-01-02    199.786667
# 2020-01-03    201.623337
# 2020-01-06    205.533340
# 2020-01-07    207.770004
# 2020-01-08    206.943329
#                  ...
# 2025-07-22           NaN
# 2025-07-23           NaN
# 2025-07-24           NaN
# 2025-07-25           NaN
# 2025-07-28           NaN
# Name: Close, Length: 1399, dtype: float64

# %%
tsla_df.plot()
tsla_df.shift(-365).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_df.rolling(5).mean()
# Out:
# Date
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08     30.480133
#                  ...
# 2025-07-22    326.265997
# 2025-07-23    328.443994
# 2025-07-24    325.621991
# 2025-07-25    322.903992
# 2025-07-28    322.323993
# Name: Close, Length: 1399, dtype: float64

# %%
tsla_df.plot()
tsla_df.rolling(5).mean().plot()
tsla_df.rolling(20).mean().plot()
plt.show()

# %% [markdown]
# # 교재 자전거 실습

# %% [markdown]
# p.234

# %%
data = pd.read_csv(bicycle_url)
data.head()
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0  11/01/2019 12:00:00 AM                  12.0                           7.0
# 1  11/01/2019 01:00:00 AM                   7.0                           0.0
# 2  11/01/2019 02:00:00 AM                   1.0                           0.0
# 3  11/01/2019 03:00:00 AM                   6.0                           6.0
# 4  11/01/2019 04:00:00 AM                   6.0                           5.0
#
#    Fremont Bridge West Sidewalk
# 0                           5.0
# 1                           7.0
# 2                           1.0
# 3                           0.0
# 4                           1.0

# %%
data.columns
# Out:
# Index(['Date', 'Fremont Bridge Total', 'Fremont Bridge East Sidewalk',
#        'Fremont Bridge West Sidewalk'],
#       dtype='object')

# %%
#data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y %I:%M:%S %p')

# %%
data = data.sort_values('Date')

# %%
data = data.set_index(['Date'])

# %%
data.columns
# Out:
# Index(['Fremont Bridge Total', 'Fremont Bridge East Sidewalk',
#        'Fremont Bridge West Sidewalk'],
#       dtype='object')

# %%
data.columns = ['Total', 'West', 'East']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147278 entries, 2012-10-03 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Total   147256 non-null  float64
#  1   West    147256 non-null  float64
#  2   East    147255 non-null  float64
# dtypes: float64(3)
# memory usage: 4.5 MB

# %%
data.describe()
# Out:
#                Total           West           East
# count  147256.000000  147256.000000  147255.000000
# mean      110.340794      50.077504      60.263699
# std       140.421808      64.633895      87.252147
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000

# %%
data.dropna().describe()
# Out:
#                Total           West           East
# count  147255.000000  147255.000000  147255.000000
# mean      110.341462      50.077763      60.263699
# std       140.422051      64.634038      87.252147
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count')
# Out:
# Text(0, 0.5, 'Hourly Bicycle Count')

# %%
weekly = data.resample('W').sum()
weekly.plot(style=[':','--','-'])
plt.ylabel('Weekly bicycle count')
# Out:
# Text(0, 0.5, 'Weekly bicycle count')

# %%
daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':','--','-'])
plt.ylabel('mean hourly count')
# Out:
# Text(0, 0.5, 'mean hourly count')

# %%
daily.rolling(50, center=True, win_type='gaussian').sum(std=10).plot(style=[':','--','-'])
# Out:
# <Axes: xlabel='Date'>

# %%
by_time = data.groupby(data.index.time).mean()
hourly_ticks = 4*60*60*np.arange(6)
by_time.plot(xticks=hourly_ticks, style=[':','--','-'])
# Out:
# <Axes: xlabel='time'>

# %%
by_weekday =  data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':','--','-'])
# Out:
# <Axes: >

# %%
weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()
by_time.head(), by_time.tail()
# Out:
# (                     Total      West      East
#  Weekday 00:00:00  9.104423  3.873461  5.230962
#          01:00:00  4.518468  2.015960  2.502508
#          02:00:00  3.006612  1.470360  1.536252
#          03:00:00  2.588919  1.328773  1.260146
#          04:00:00  7.445280  4.037620  3.408438,
#                        Total       West       East
#  Weekend 19:00:00  57.801256  28.009138  29.792119
#          20:00:00  41.281553  19.373501  21.908053
#          21:00:00  29.432895  13.455740  15.977156
#          22:00:00  21.700171   9.684180  12.015991
#          23:00:00  16.897773   6.960023   9.937750)

# %%
fig, axes = plt.subplots(1,2,figsize=(14,5))
by_time.loc['Weekday'].plot(ax=axes[0], title='Weekdays',
                            xticks=hourly_ticks, style=[':','--','-'])
by_time.loc['Weekend'].plot(ax=axes[1], title='Weekends',
                            xticks=hourly_ticks, style=[':','--','-'])
# Out:
# <Axes: title={'center': 'Weekends'}, xlabel='time'>
